# %%
import matplotlib.pyplot as plt
from strucpara.analysis import GrooveAgent
rootfolder = '/Volumes/TOSHIBA_2T/Hsin-Yun/cg_13/analysis/meth3/major_minor_g'

# %% [markdown]
# ### Part 1: Initialize

# %%
time_interval = '0_1us' # '0_1us', '1_2us', '2_3us', '3_4us', '4_5us'
bp_agent = GrooveAgent(rootfolder, time_interval)

# %% [markdown]
# ### Part 2: Histogram for parameters

# %%
figsize = (24, 6)
bins = 50
sele_para = 'major_gw_pp' #'major_gw_pp', 'major_gw_refined', 'minor_gw_pp', 'minor_gw_refined'
xlines = range(5,28,2)
xlim = (5,26)
ylim = None

fig, axes = bp_agent.histogram_groups(figsize, sele_para, bins, xlines, xlim, ylim)
plt.tight_layout()
plt.savefig(f'{sele_para}.png')
plt.savefig(f'{sele_para}.svg')
plt.show()

# %%
# figsize = (12, 4)
# bins = 50
# sele_para = 'major_gw_refined' #'major_gw_pp', 'major_gw_refined', 'minor_gw_pp', 'minor_gw_refined'
# xlines = range(12,28,2)
# xlim = (12,28)
# ylim = None

# fig, axes = bp_agent.histogram_three_groups(figsize, sele_para, bins, xlines, xlim, ylim)
# plt.tight_layout()
# #plt.savefig(f'{sele_para}.svg')
# plt.show()

# %%
figsize = (24, 6)
bins = 50
sele_para = 'minor_gw_pp' #'major_gw_pp', 'major_gw_refined', 'minor_gw_pp', 'minor_gw_refined'
xlines = range(0,28,2)
xlim = (5, 26)
ylim = None

fig, axes = bp_agent.histogram_groups(figsize, sele_para, bins, xlines, xlim, ylim)
plt.tight_layout()
plt.savefig(f'{sele_para}.png')
plt.savefig(f'{sele_para}.svg')
plt.show()

# %%
# figsize = (12, 4)
# bins = 50
# sele_para = 'minor_gw_refined' #'major_gw_pp', 'major_gw_refined', 'minor_gw_pp', 'minor_gw_refined'
# xlines = range(5,20,2)
# xlim = (5,20)
# ylim = None

# fig, axes = bp_agent.histogram_three_groups(figsize, sele_para, bins, xlines, xlim, ylim)
# plt.tight_layout()
# #plt.savefig(f'{sele_para}.svg')
# plt.show()

# %%
figsize = (12, 4)
bins = 100
sele_para = 'slide' #'shift', 'tilt', 'slide', 'roll', 'rise', 'twist'
xlines = range(-3,3)
xlim = (-3,2)
ylim = None

fig, axes = bp_agent.histogram_three_groups(figsize, sele_para, bins, xlines, xlim, ylim)
plt.tight_layout()
#plt.savefig(f'{sele_para}.svg')
plt.show()

# %%
figsize = (12, 4)
bins = 100
sele_para = 'roll' #'shift', 'tilt', 'slide', 'roll', 'rise', 'twist'
xlines = range(-20,35,10)
xlim = (-25,30)
ylim = None

fig, axes = bp_agent.histogram_three_groups(figsize, sele_para, bins, xlines, xlim, ylim)
plt.tight_layout()
plt.savefig(f'{sele_para}.svg')
plt.show()

# %%
figsize = (12, 4)
bins = 100
sele_para = 'rise' #'shift', 'tilt', 'slide', 'roll', 'rise', 'twist'
xlines = np.arange(2,5,0.5)
xlim = (2,5)
ylim = None

fig, axes = bp_agent.histogram_three_groups(figsize, sele_para, bins, xlines, xlim, ylim)
plt.tight_layout()
#plt.savefig(f'{sele_para}.svg')
plt.show()

# %%
figsize = (12, 4)
bins = 100
sele_para = 'twist' #'shift', 'tilt', 'slide', 'roll', 'rise', 'twist'
xlines = range(10,60,10)
xlim = (10,60)
ylim = None

fig, axes = bp_agent.histogram_three_groups(figsize, sele_para, bins, xlines, xlim, ylim)
plt.tight_layout()
#plt.savefig(f'{sele_para}.svg')
plt.show()

# %% [markdown]
# ### Part 3: Twist bimodal further analysis

# %%
figsize = (12, 8)
bins = 100
sele_para = 'twist' #'shift', 'tilt', 'slide', 'roll', 'rise', 'twist'
xlines = []
xlim = None
ylim = None

fig, ax = bp_agent.histogram_bimodal(figsize, sele_para, bins, xlines, xlim, ylim)
plt.tight_layout()
#plt.savefig(f'twist_bimodal.png', dpi=150)
plt.show()
